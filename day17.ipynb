# %% [markdown]
# ## API

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://real-time-amazon-data.p.rapidapi.com/product-category-list?country=US')

# %%
url = "'https://real-time-amazon-data.p.rapidapi.com/product-category-list?country=US"
headers = {
    "X-RapidAPI-Key" : 'real-time-amazon-data.p.rapidapi.com'
    "X-RapidAPI-Host" 'd788df8b1dmshc29167bda09d4d4p1d8445jsn3e9af81f6abc'
}




response = requests.get(url, headers=headers,)
# Out:
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[15], line 10
#       1 url = "'https://real-time-amazon-data.p.rapidapi.com/product-category-list?country=US"
#       2 headers = {
#       3     "X-RapidAPI-Key" : 'real-time-amazon-data.p.rapidapi.com'
#       4     "X-RapidAPI-Host" 'd788df8b1dmshc29167bda09d4d4p1d8445jsn3e9af81f6abc'
#       5 }
# ---> 10 response = requests.get(url, headers=headers,)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("real-time-amazon-data.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "d788df8b1dmshc29167bda09d4d4p1d8445jsn3e9af81f6abc",
    'x-rapidapi-host': "real-time-amazon-data.p.rapidapi.com",
    'Content-Type': "application/json"
}

conn.request("GET", "/seller-profile?seller_id=A02211013Q5HP3OMSZC7W&country=US", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# Cell In[16], line 11
#       3 conn = http.client.HTTPSConnection("real-time-amazon-data.p.rapidapi.com")
#       5 headers = {
#       6     'x-rapidapi-key': "d788df8b1dmshc29167bda09d4d4p1d8445jsn3e9af81f6abc",
#       7     'x-rapidapi-host': "real-time-amazon-data.p.rapidapi.com",
#       8     'Content-Type': "application/json"
#       9 }
# ---> 11 conn.request("GET", "/seller-profile?seller_id=A02211013Q5HP3OMSZC7W&country=US", headers=headers)
#      13 res = conn.getresponse()
#      14 data = res.read()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 def request(self, method, url, body=None, headers={}, *,
#    1336             encode_chunked=False):
# ...
