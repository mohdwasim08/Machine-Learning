# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cars = pd.read_csv('cars.csv')

# %%
cars.shape
# Out:
# (8128, 5)

# %%
cars.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          8128 non-null   object
#  1   km_driven      8128 non-null   int64
#  2   fuel           8128 non-null   object
#  3   owner          8128 non-null   object
#  4   selling_price  8128 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 317.6+ KB

# %%
Dtype 
---  ------         --------------  ----- 
 0   brand          8128 non-null   object
 1   km_driven      8128 non-null   int64

# %%
cars.isnull().sum()
# Out:
# brand            0
# km_driven        0
# fuel             0
# owner            0
# selling_price    0
# dtype: int64

# %%
cars.duplicated().sum()
# Out:
# np.int64(1678)

# %%
cars.head(3)
# Out:
#     brand  km_driven    fuel         owner  selling_price
# 0  Maruti     145500  Diesel   First Owner         450000
# 1   Skoda     120000  Diesel  Second Owner         370000
# 2   Honda     140000  Petrol   Third Owner         158000

# %%
# scatter plot
sns.scatterplot(
    x=cars['km_driven'],
    y=cars['selling_price'],

)
# Out:
# <Axes: xlabel='km_driven', ylabel='selling_price'>

# %% [markdown]
# **Observation**
# - genrally lower km --> higher selling price

# %%
#Barplot
cars.head(3)
# Out:
#     brand  km_driven    fuel         owner  selling_price
# 0  Maruti     145500  Diesel   First Owner         450000
# 1   Skoda     120000  Diesel  Second Owner         370000
# 2   Honda     140000  Petrol   Third Owner         158000

# %%
sns.barplot(
    x=cars['fuel'],
    y=cars['selling_price'],
    
)
# Out:
# <Axes: xlabel='fuel', ylabel='selling_price'>

# %%
sns.boxplot(
    x = cars['owner'],

    y = cars['selling_price']
)
# Out:
# <Axes: xlabel='owner', ylabel='selling_price'>

# %%
sns.heatmap(pd.crosstab(cars['brand'],cars['owner']) )
# Out:
# <Axes: xlabel='owner', ylabel='brand'>

# %%
cars.head(3)
# Out:
#     brand  km_driven    fuel         owner  selling_price
# 0  Maruti     145500  Diesel   First Owner         450000
# 1   Skoda     120000  Diesel  Second Owner         370000
# 2   Honda     140000  Petrol   Third Owner         158000

# %%
sns.clustermap(pd.crosstab(cars['brand'],cars['fuel']) )

# %%
sns.heatmap(cars.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
netflix = pd.read_csv('Netflix.csv')

# %%
netflix.head()
# Out:
#             Titles  Year Rating  IMDB_Rating  Netflix
# 0     Breaking Bad  2008    18+          9.5        1
# 1  Game of Thrones  2011    18+          9.3        0
# 2   Rick and Morty  2013    18+          9.2        0
# 3             Dark  2017    16+          8.8        1
# 4  Stranger Things  2016    16+          8.8        1

# %%
sns.heatmap(
    pd.crosstab(
        netflix['Titles'],
        netflix['Rating']
    )
)
# Out:
# <Axes: xlabel='Rating', ylabel='Titles'>

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Titles       50 non-null     object
#  1   Year         50 non-null     int64
#  2   Rating       50 non-null     object
#  3   IMDB_Rating  50 non-null     float64
#  4   Netflix      50 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.1+ KB

# %%
# Clustermap
sns.clustermap(
    pd.crosstab(
        netflix['Titles'],
        netflix['Rating']
    )
)

# %%
netflix.head()
# Out:
#             Titles  Year Rating  IMDB_Rating  Netflix
# 0     Breaking Bad  2008    18+          9.5        1
# 1  Game of Thrones  2011    18+          9.3        0
# 2   Rick and Morty  2013    18+          9.2        0
# 3             Dark  2017    16+          8.8        1
# 4  Stranger Things  2016    16+          8.8        1

# %%
netflix.shape
# Out:
# (50, 5)

# %%
#line plot
sns.lineplot(
    x=netflix['Year'],
    y=netflix['IMDB_Rating'],
  
   
)
# Out:
# <Axes: xlabel='Year', ylabel='IMDB_Rating'>

# %%
#pairplot
sns.pairplot(netflix,hue='Rating')
